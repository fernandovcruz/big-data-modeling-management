# %% [markdown]
# <font size="8">Homework 2: Mini Project - AirBnb Document Database</font>
#
# Group number: `25`
#
# Group members:
# 1. `André Figueiredo Cruz e Cunha : 20191224`
# 2. `Catarina Ribeiro Duarte : 20191211`
# 3. `Fernando António Daio Vera Cruz : 20220646`
# 4. `Pedro Ricardo Félix Fernandes : 20220592`
#
# The Homework 2 is comprised of two parts:
# 1. Data modelling
# 2. Queries to database to answer the questions

# %% [markdown]
# <font size="6">1. Data Modelling</font>
#
# <font size="4">Congratulations! You have been successfully hired as the new Data Engineering and Management team in the AirBNB Business Intelligence department.
# The organization is undergoing restructuring as the performance of the previous teams was not believed to be satisfactory.
#
# Before leaving their post, the head of the Data Modelling department left this note of identified issues.
#
# Currently a lot of data related to AirBNB listings is all collected in the same document. While this has some advantages it has also caused issues. The query performance is known to be too slow, so some decisions on hybridization of data models are required. The previous team did not have experience in the application of patterns, which has been identified as a key area to improve performance through the enhancement of the data model. Indexes have also not been previously applied.
#
# The AirBNB application use has been growing rapidly, especially the the number of reviews. Because of that we have been overwriting them regularly, but the business intelligence department will benefit from storing all the Reviews and analysing them over time.
#
# Finally, there are some mistakes in the data collection : for instance, writing the same data multiple times, and assigning wrong timestamps for when transactions occurred. The new team will need to decide how to address these.
#
# In your new role, you are expected to think about the database use case in each question, analyse all the information you have, how commonly is this query needed, how heavy will it be on reads and write etc. You should modify the database schema, where you deem appropriate, to optimise for the business use cases. To do so you should use all the tools you have learned in the lab and lectures, especially embedding and linking, indexes, and patterns. This can involve creating new fields, documents, and collections. Indicate which pattern you are applying and your reasoning for doing so in comments, remember to identify any duplication that is required and any risks of staleness.
#
# Remember to think about the relevancy of all data that will be returned in each case and if this is needed or adding excessive time to return:
# 1. to streamline the data collection system;
# 2. to clean up the data and optimise what will be returned for each use case;
# 3. to use correct patterns to improve speed of typical queries;
# 4. to ensure that all departments receive correct and relevant information from the database;
# 5. to provide the data model schema to inform other departments of the changes.
#
# Good practices in our company include:
# 1. all newly created fields have CAPITALIZED names;
# 2. all new queries function on the most updated version of the database (if you make multiple changes all your queries still work after the final changes);
# 3. for some of the queries you will likely want to change the database schema in some way. Each database transformation choice is properly documented using format:
#     * `TRANSFORMATION APPLIED: <NAME and DESCRIPTION OF TRANSFORMATION>`
#     * `REASONING BEHIND: <WHY YOU DID IT>`
#     * `EXPECTED RESULT: <WHAT IS THE (EXPECTED) RESULT OF RUNNING QUERIES GIVEN THIS TRANSFORMATION>`
#
# </font>

# %% [markdown]
# **Initial data setup:**
#
# Before starting on the queries below review the data and look to adjust the schema for the typical use case described below.
#
# 1) The most typical use case for the database is to show information relating to a property listing to a customer. This is done by a query to the database which returns one of the listing documents. Currently a lot of time is spent when a listing is retrieved from the database to show to a customer. Decide what information should be returned in a typical query and optimise the structure for this use case. For example, we typically only want a sample of reviews but not all reviews (although all reviews ), the customer does not need to know past transaction data, etc. Update the document schema for this typical use case. This may involve the creation of new collections and documents.
#
# 2) Review the data for any errors (such as transactions that don’t fit the listing) or inappropriate duplication and clean up as appropriate.

# %% [markdown]
# <font size="6">2. Uses for the database</font>
#
# <font size="4">Different AirBNB departments require different analytics from our common database.
# Here are the list of all specific questions from different departments:
#
# **Standard Dificulty Questions:**
#
# 3)	Once per month we like to reward hosts with recognition. Pick three superhosts who have at least two property listings that can accommodate more than four people?
#
# 4)	One of employees is thinking of buying a property to rent out. Which bed type is most common in the listings that have waterfront and a dishwasher in New York?
#
# 5)	We are thinking of identifying someone to hire to write review for us professionally. What is the name of the reviewer who left the longest review in New York?
#
# 6)	We are thinking of trying to assess the security of different areas based on the security deposit required. What is the biggest and smallest difference between the price and deposit for security per number of visitors staying at the property?
#
# 7)	We want to identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. We will use this information to target advertising of different customers. It is not expected this information will change much over time so we won’t look to update it we just would like a current view. What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? For each property type return the city with the highest and lowest average value.
#
# **Advanced Dificulty Questions (Remember to consider how to optimise the database for these queries):**
#
# 8)	We want to have a new webpage for hosts when setting up their account. It will list suggested typical amenities. This data will need to be available every time a host registers a property but is not expected to change very much. The starting point for the list will be all unique amenities currently listed in properties (across all documents). Optimise the database for this use case and show how the data should be queried.
#
# 9)	We want to start tracking our reviewers better. We want to create a webpage that shows the top 20 reviewers and the count of the number of reviews of each of these reviewers. This webpage should be kept up to date. It should also have a link to return the number of reviews for a given reviewer ID or Name (show how to query for number of reviews by ID or query quickly).
#
#
# 10)	For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). We are thinking we may soon add more metrics, although we don’t know what these will be. We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. Adjust the data model so this can be done and show the query for an example property.
#
# 11)	We wish to be able to have better access to information about transaction, we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.
#
#
# 12)	We wish to have a summary webpage that displays information about our top destinations. This webpage should display for each of the top 10 cities some basic information about our operations in the area (number of properties by type for example, average price by type) but you can choose the metrics. For each of the top 10 cities it should also provide some basic information about the top 3 properties in each city (price, number of review, whatever you think useful) to show an example of the properties available in the area. We would like to keep this webpage up to date as information changes.
#
# **Database updates:**
#
# After you have completed the above tasks and have optimised your database show how you would complete each of the updates below. You can create whatever fictional data you like for the below. Remeber to cosider how to prevent any data you have previously created from becoming stale.
#
# 13)	Add a new property, this property should have a new host, and should be located in one of the top 10 cities. The host selects the top 10 most common amenities to be listed for the property.
#
# 14)	Add a new review to this property, the review should be from one of our top 20 reviewers.
#
# 15)	Add a new review metric called x_factor to the new document and give a score of 10. Show that the average across all metrics is correctly calculated for this listing, with the query you previously developed.

# %% [markdown]
# # Setup
#
# 1. run Jupyter
# 2. run Docker
# 3. create MongoDB container in Command Prompt: make sure you don't have 'leftover' container from previous runs
#
#         docker run --name mongodb -d -e MONGO_INITDB_ROOT_USERNAME=AzureDiamond -e MONGO_INITDB_ROOT_PASSWORD=hunter2 -p 27017:27017 mongo
#
# 4. run Studio3T
#
# 5. create New Connection OR reconnect to existing Connection:
#
#     5.A	In Studio3T create Connection:
#             a.	Press Connection -> New Connection
#             b.	Insert credentials into URI field: mongodb://AzureDiamond:hunter2@localhost:27017
#             c.	Press Test Connection
#             d.	Assign a name to the Connection (top empty line) -> Save
#             e.	Press Connect
#
#     5.B In Studio3T reconnect to Connection:
#             a. press Connect (top left corner)
#             b. choose MongoDB connection  -> press Connect (MongoDB container must be runnning by this time)
#
# 6.	In Studio3T import the Database:
#             a.	Press Import
#             b.	Choose BSON mongodump archive
#             c.	Find your database path
#             d.	Select All file formats and choose the database file ‘sampledata.archive’
#             e.	Press Run: be patient while the database loads
#             f.	Inspect the collections and documents
#
# Done!

# %%
# Python Connector

# !pip install pymongo
# or #!conda install -y pymongo

from datetime import datetime
from pprint import pprint
import time
from bson.objectid import ObjectId
import random


from pymongo import MongoClient

user="AzureDiamond"
password="hunter2"
host="localhost"
port="27017"
protocol="mongodb"

client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# Database check
db = client.sample_airbnb 
print(f"Database info: {db}\n")
db.name
# Out:
# ...
# Database info: Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_airbnb')
# 'sample_airbnb'

# %% [markdown]
# # Loading and Inspecting database

# %%
# Collections are inside our Database 'sample_analytics'

collection_list = db.list_collection_names()

print(f"The database contains {len(collection_list)} collections")
print(f"All collections: {collection_list[0:]}")
print(f"Collection {collection_list[0]} contains {db[collection_list[0]].count_documents({})} documents")
# Out:
# The database contains 6 collections
# All collections: ['amenities', 'user_use_case', 'reviews', 'listingsAndReviews_new', 'schema1', 'rooms']
# Collection amenities contains 186 documents

# %% [markdown]
# [PyMongo documentation](https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html)

# %%
collection = db["listingsAndReviews_new"]

# %%
document1 = collection.find_one()
document1
# Out:
# {'_id': '10006546',
#  'listing_url': 'https://www.airbnb.com/rooms/10006546',
#  'name': 'Ribeira Charming Duplex',
#  'summary': 'Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.',
# ...

# %% [markdown]
# ### Question 1

# %% [markdown]
# 1) The most typical use case for the database is to show information relating to a property listing to a customer. This is done by a query to the database which returns one of the listing documents. Currently a lot of time is spent when a listing is retrieved from the database to show to a customer. Decide what information should be returned in a typical query and optimise the structure for this use case. For example, we typically only want a sample of reviews but not all reviews (although all reviews ), the customer does not need to know past transaction data, etc. Update the document schema for this typical use case. This may involve the creation of new collections and documents.

# %%
db.listingsAndReviews_new.aggregate([
    {"$project": {"_id":1,
                  "access":1,
                  "accommodates":1,
                  "address.country":1,
                  "address.street":1,
                  "address.market":1,
                  "amenities":1,
                  "bathrooms":1,
                  "bedrooms":1,
                  "beds":1,
                  "bed_type":1,
                  "cancellation_policy":1,
                  "cleaning_fee":1,
                  "description":1,
                  "extra_people":1,
                  "guests_included":1,
                  "host_about":1,
                  "host_identity_verified":1,
                  "host_is_superhost":1,
                  "host_listings_count":1,
                  "host_name":1,
                  "host_response_rate":1,
                  "host_response_time":1,
                  "house_rules":1,
                  "interaction":1,
                  "maximum_nights":1,
                  "minimum_nights":1,
                  "name":1,
                  "neighborhood_overview":1,
                  "notes":1,
                  "number_of_reviews":1,
                  "price":1,
                  "property_type":1,
                  "review_scores_checkin":1,
                  "review_scores_cleanliness":1,
                  "review_scores_communication":1,
                  "review_scores_location":1,
                  "review_scores_rating":1,
                  "review_scores_value":1,
                  "reviews": 1,
                  "room_type":1,
                  "security_deposit":1,
                  "summary":1,
                  "transit":1}},
    {
    "$out": "user_use_case"
    }
])

  #  * `TRANSFORMATION APPLIED: $project , filtered the fileds that belong to the original collection.
   # * `REASONING BEHIND: prepare a colection for the most typical use case for the database, this is, to show information relating to a property listing to a customer
    #* `EXPECTED RESULT: ony show relevant fileds and the 5 most recent reviews

# %%
db.listingsAndReviews_new.aggregate([
    {"$project": {"_id":1,
                  "access":1,
                  "accommodates":1,
                  "address.country":1,
                  "address.street":1,
                  "address.market":1,
                  "amenities":1,
                  "bathrooms":1,
                  "bedrooms":1,
                  "beds":1,
                  "bed_type":1,
                  "cancellation_policy":1,
                  "cleaning_fee":1,
                  "description":1,
                  "extra_people":1,
                  "guests_included":1,
                  "host_about":1,
                  "host_identity_verified":1,
                  "host_is_superhost":1,
                  "host_listings_count":1,
                  "host_name":1,
                  "host_response_rate":1,
                  "host_response_time":1,
                  "house_rules":1,
                  "interaction":1,
                  "maximum_nights":1,
                  "minimum_nights":1,
                  "name":1,
                  "neighborhood_overview":1,
                  "notes":1,
                  "number_of_reviews":1,
                  "price":1,
                  "property_type":1,
                  "review_scores_checkin":1,
                  "review_scores_cleanliness":1,
                  "review_scores_communication":1,
                  "review_scores_location":1,
                  "review_scores_rating":1,
                  "review_scores_value":1,
                  "reviews": 1,
                  "room_type":1,
                  "security_deposit":1,
                  "summary":1,
                  "transit":1,
                  "transactions":1}},
    {
    "$out": "schema1"
    }
])


  #  * `TRANSFORMATION APPLIED: $project , filtered the fileds that belong to the original collection.
   # * `REASONING BEHIND: prepare a colection for the anlyses business based of the database, this is, to show information relating to a property listing to a stakeholder
    #* `EXPECTED RESULT: ony show relevant fileds

# %%
pipeline = list(
    db.listingsAndReviews_new.aggregate([
    {"$unwind": "$reviews"},
    
    {"$project": {
        "_id": "$reviews._id",
        "reviews.date": 1,
        "reviews.listing_id": 1,
        "reviews.reviewer_id": 1,
        "reviews.reviewer_name": 1,
        "reviews.comments": 1
    }},

    {"$out" : "reviews"}
]

))

  #  * `TRANSFORMATION APPLIED: $project , filtered the fileds that belong to the original collection.
   # * `REASONING BEHIND: break the embedded relation of listings and reviews. So, this way we have the reviews in their own collection facilitating the alysis of this filed since it can grow a lot on size as wel as have a recurent updated
    #* `EXPECTED RESULT: A collection where every document is a review for a identified listing_id.

# %% [markdown]
# ### Question 2

# %% [markdown]
# 2) Review the data for any errors (such as transactions that don’t fit the listing) or inappropriate duplication and clean up as appropriate.

# %%
db.user_use_case.update_many({}, {"$mul": {"review_scores_rating": 0.1}})
db.schema1.update_many({}, {"$mul": {"review_scores_rating": 0.1}})

 #  * `TRANSFORMATION APPLIED: $mul,  this function multiplies the value of a field by a specified number, in our case 0.1, this is, divides by 10.
   # * `REASONING BEHIND: the review_scores_rating is the only of the review scores fields that ranges until 100, so we wanted to fix this scale
    #* `EXPECTED RESULT: the same collection however, for every document the review_scores_rating filed is divided by 10.

# %%
# update the collection to convert string fields to integer fields
db.schema1.update_many({}, [
  {"$set": {"maximum_nights": {"$toInt": "$maximum_nights"}, "minimum_nights": {"$toInt": "$minimum_nights"}}}
])
db.suser_use_case.update_many({}, [
  {"$set": {"maximum_nights": {"$toInt": "$maximum_nights"}, "minimum_nights": {"$toInt": "$minimum_nights"}}}
])

 #  * `TRANSFORMATION APPLIED: $toInt,  this function transforms the field value into a integer
   # * `REASONING BEHIND: This field corresponds to a number but was saved as a string
    #* `EXPECTED RESULT: the same collection, documents and filed value but, this time around, the field is saved as an Integer.

# %%
#from datetime import datetime

db.schema1.update_many(
    { "transactions.transactions.date": { "$lt": datetime(2008, 1, 1) } },
    { "$set": { "transactions.transactions.$[elem].date": datetime(2008, 1, 1) } },
    array_filters=[{"elem.date": {"$lt": datetime(2008, 1, 1)}}]

)


 #  * `TRANSFORMATION APPLIED: $lt, this functions finds the values that are less than the user defined. $set,  this function transforms the field value into the desired expression
   # * `REASONING BEHIND: The date field in transactions  corresponds to the date that the payment transactions were made for that listing. In this field, some dates were from before thatn 2008, this cannot be possible since the AIRBNB website only founded in that year. Making payments before that impossible. So, since we simply opted to attched the earliest date possible, 2008/1/1
    #* `EXPECTED RESULT: All transaction dates whithin every document that were older that 2008 were set to 2008/01/01.

# %%
document_test = db.schema1.find_one()
document_test
# Out:
# {'_id': '10006546',
#  'name': 'Ribeira Charming Duplex',
#  'summary': 'Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.',
# ...

# %% [markdown]
# ### Question 3

# %% [markdown]
# 3)	Once per month we like to reward hosts with recognition. Pick three superhosts who have at least two property listings that can accommodate more than four people?

# %%
pipeline = list( 
    db.schema1.aggregate([ 
        {"$match": {"host_is_superhost": True,
                    "host_listings_count": {"$gte": 2},      
                    "accommodates" : {"$gt": 4}}},
        {"$limit": 3}     
        ] ) ) 

for result in pipeline:
    print(result["host_name"])
# Out:
# Nate
# Roberta (Beta) Gatti
# Luiz Henrique

# %% [markdown]
# ### Question 4

# %% [markdown]
# 4)	One of employees is thinking of buying a property to rent out. Which bed type is most common in the listings that have waterfront and a dishwasher in New York?

# %%
pipeline = list( 
    db.schema1.aggregate([
        {"$match": {
            "address.market": "New York", 
            "amenities": {"$all": ["Waterfront", "Dishwasher"]}},
        
        },
        {"$group": {
            "_id": "$bed_type",
            "count": {"$sum": 1}
        }},
        {"$sort": {
            "count": -1
        }}
    ]) 
)

pprint(pipeline)
# Out:
# [{'_id': 'Real Bed', 'count': 1}]

# %% [markdown]
# ### Question 5

# %% [markdown]
# 5)	We are thinking of identifying someone to hire to write review for us professionally. What is the name of the reviewer who left the longest review in New York?

# %%
pipeline = list(
    db.schema1.aggregate([
    {
    "$match": {"address.market": "New York"}
    },
    {
    '$unwind': '$reviews'
    },
    {
    '$match': {'reviews.comments': {'$exists': True, '$ne': ''}}
    },
    {
    '$project': {"_id":0,
                 "Reviewer": "$reviews.reviewer_name",
                 "Length": {"$strLenCP":"$reviews.comments"}} 
    },
    {
    '$sort': {'Length':-1}
    },
    {
    '$limit': 1
}

]

))

pprint(pipeline)
# Out:
# [{'Length': 4665, 'Reviewer': 'Angela'}]

# %% [markdown]
# ### Question 6

# %% [markdown]
# 6)	We are thinking of trying to assess the security of different areas based on the security deposit required. What is the biggest and smallest difference between the price and deposit for security per number of visitors staying at the property?

# %%
pipeline = list( 
    db.schema1.aggregate([
    {"$project": {
        "_id": 0,
        "guests_included": {"$toDouble": "$guests_included"},
        "price": {"$toDouble": "$price"},
        "security_deposit": {"$toDouble": "$security_deposit"}
    }},
    {"$project": {
        "guests_included": 1,
        "price_security_diff":{"$abs": {"$subtract": ["$price", "$security_deposit"]}}
    }},
    {"$group": {
        "_id": "$guests_included",
        "max_diff": {"$max": "$price_security_diff"},
        "min_diff": {"$min": "$price_security_diff"}
    }},
    {"$project" : {"_id": 0,
                   "Guests included" : "$_id",
                   "max_diff" : 1,
                   "min_diff" : 1 }},
    {"$sort":{"Guests included": 1}}
]))

pprint(pipeline)
# Out:
# [{'Guests included': 1.0, 'max_diff': 38459.0, 'min_diff': 0.0},
#  {'Guests included': 2.0, 'max_diff': 29148.0, 'min_diff': 0.0},
#  {'Guests included': 3.0, 'max_diff': 3821.0, 'min_diff': 0.0},
#  {'Guests included': 4.0, 'max_diff': 11749.0, 'min_diff': 0.0},
#  {'Guests included': 5.0, 'max_diff': 4003.0, 'min_diff': 1.0},
#  {'Guests included': 6.0, 'max_diff': 1900.0, 'min_diff': 0.0},
#  {'Guests included': 7.0, 'max_diff': 1775.0, 'min_diff': 60.0},
#  {'Guests included': 8.0, 'max_diff': 19049.0, 'min_diff': 0.0},
#  {'Guests included': 9.0, 'max_diff': 451.0, 'min_diff': 40.0},
#  {'Guests included': 10.0, 'max_diff': 9330.0, 'min_diff': 31.0},
#  {'Guests included': 12.0, 'max_diff': 1500.0, 'min_diff': 80.0},
#  {'Guests included': 13.0, 'max_diff': 10498.0, 'min_diff': 1050.0},
#  {'Guests included': 15.0, 'max_diff': 2974.0, 'min_diff': 901.0},
#  {'Guests included': 16.0, 'max_diff': 460.0, 'min_diff': 250.0}]

# %% [markdown]
# ### Question 7

# %% [markdown]
# 7)	We want to identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. We will use this information to target advertising of different customers. It is not expected this information will change much over time so we won’t look to update it we just would like a current view. What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? For each property type return the city with the highest and lowest average value.

# %%
pipeline = list(
    db.schema1.aggregate([
        {
            "$project": {
                "_id": 0,
                "address.market": 1,
                "property_type": 1,
                "duration_of_stay": "$maximum_nights"
            }
        },
        {
            "$group": {
                "_id": {
                    "property_type": "$property_type",
                    "city": "$address.market"
                },
                "avg_duration_of_stay": {"$avg": "$duration_of_stay"}
            }
        },
        {
            "$sort": {"_id.city": 1}
        }
    ])
)

pprint(pipeline)
# Out:
# [{'_id': {'city': '', 'property_type': 'Apartment'},
#   'avg_duration_of_stay': 568.75},
#  {'_id': {'city': '', 'property_type': 'Townhouse'},
#   'avg_duration_of_stay': 30.0},
#  {'_id': {'city': '', 'property_type': 'Condominium'},
#   'avg_duration_of_stay': 30.0},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Other'},
#   'avg_duration_of_stay': 1125.0},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Apartment'},
#   'avg_duration_of_stay': 1359.252808988764},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Tiny house'},
#   'avg_duration_of_stay': 1125.0},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Loft'},
#   'avg_duration_of_stay': 607.2105263157895},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Aparthotel'},
#   'avg_duration_of_stay': 780.0},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Guest suite'},
#   'avg_duration_of_stay': 1125.0},
#  {'_id': {'city': 'Barcelona', 'property_type': 'Villa'},
#   'avg_duration_of_stay': 15.0},
# ...

# %%
pipeline = list(
    db.schema1.aggregate([
    {
        "$project": {
            "address.market": 1,
            "property_type": 1,
            "duration_of_stay": "$maximum_nights"
        }
    },
    {
        "$group": {
            "_id": {
                "city": "$address.market",
                "property_type": "$property_type"
            },
            "avg_duration_of_stay": {"$avg": "$duration_of_stay"}
        }
    },
    {
        "$sort": {"_id.property_type": 1, "avg_duration_of_stay": 1}
    },
    {
        "$group": {
            "_id": "$_id.property_type",
            "lowest_avg_duration_of_stay": {"$first": "$avg_duration_of_stay"},
            "lowest_city": {"$first": "$_id.city"},
            "highest_avg_duration_of_stay": {"$last": "$avg_duration_of_stay"},
            "highest_city": {"$last": "$_id.city"}
        }
    }
]))

#result = list(db.listings.aggregate(pipeline))

pprint(pipeline)
# Out:
# [{'_id': 'Apartment',
#   'highest_avg_duration_of_stay': 5200437.653753026,
#   'highest_city': 'Istanbul',
#   'lowest_avg_duration_of_stay': None,
#   'lowest_city': None},
#  {'_id': 'Barn',
#   'highest_avg_duration_of_stay': 1125.0,
#   'highest_city': 'The Big Island',
#   'lowest_avg_duration_of_stay': 1125.0,
#   'lowest_city': 'The Big Island'},
#  {'_id': 'Heritage hotel (India)',
#   'highest_avg_duration_of_stay': 14.0,
#   'highest_city': 'Hong Kong',
#   'lowest_avg_duration_of_stay': 14.0,
#   'lowest_city': 'Hong Kong'},
#  {'_id': 'Train',
#   'highest_avg_duration_of_stay': 1125.0,
#   'highest_city': 'Sydney',
#   'lowest_avg_duration_of_stay': 1125.0,
#   'lowest_city': 'Sydney'},
#  {'_id': 'Camper/RV',
#   'highest_avg_duration_of_stay': 1125.0,
#   'highest_city': 'Montreal',
#   'lowest_avg_duration_of_stay': 30.0,
#   'lowest_city': 'Porto'},
#  {'_id': 'Hostel',
#   'highest_avg_duration_of_stay': 1125.0,
#   'highest_city': 'New York',
# ...

# %% [markdown]
# ### Question 8

# %% [markdown]
# 8.We want to have a new webpage for hosts when setting up their account. It will list suggested typical amenities. This data will need to be available every time a host registers a property but is not expected to change very much. The starting point for the list will be all unique amenities currently listed in properties (across all documents). Optimise the database for this use case and show how the data should be queried.

# %%
pipeline = list(
    db.schema1.aggregate([
    {
        "$unwind": "$amenities"
    },
    {
        "$group": {
            "_id": "$amenities"
        }
    },
    {
        "$sort": {"amenity": 1}
    },
    
    {"$out": 'amenities'}
]

 ) )

pprint(list(db.amenities.find()[:]))
# Out:
# [{'_id': 'Stair gates'},
#  {'_id': 'Flat path to front door'},
#  {'_id': 'Oven'},
#  {'_id': 'Building staff'},
#  {'_id': 'Dining area'},
#  {'_id': 'Well-lit path to entrance'},
#  {'_id': 'Game console'},
#  {'_id': 'Pets live on this property'},
#  {'_id': 'Home theater'},
#  {'_id': 'Netflix'},
#  {'_id': 'Heated towel rack'},
#  {'_id': 'Bicycle'},
#  {'_id': 'Refrigerator'},
#  {'_id': 'Memory foam mattress'},
#  {'_id': 'Beach essentials'},
#  {'_id': 'Pool'},
#  {'_id': 'Garden or backyard'},
#  {'_id': 'Indoor fireplace'},
#  {'_id': 'Other pet(s)'},
#  {'_id': 'Pack ’n Play/travel crib'},
#  {'_id': 'Wide hallway clearance'},
#  {'_id': 'Bath towel'},
#  {'_id': 'Toilet paper'},
#  {'_id': 'Hot water kettle'},
#  {'_id': 'Rain shower'},
#  {'_id': 'Fixed grab bars for toilet'},
#  {'_id': 'Crib'},
#  {'_id': 'Hangers'},
#  {'_id': 'Lake access'},
#  {'_id': 'Cooking basics'},
#  {'_id': 'Roll-in shower'},
#  {'_id': 'Step-free access'},
# ...

# %% [markdown]
# ### Question 9

# %% [markdown]
# 9.We want to start tracking our reviewers better. We want to create a webpage that shows the top 20 reviewers and the count of the number of reviews of each of these reviewers. This webpage should be kept up to date. It should also have a link to return the number of reviews for a given reviewer ID or Name (show how to query for number of reviews by ID or query quickly).

# %%
pipeline = [
    {
        '$unwind': '$reviews'
    },
    {
        '$match': {'reviews.comments': {'$exists': True, '$ne': ''}}
    },
    {
        '$group': {
            '_id': '$reviews.reviewer_id',
            'num_reviews': {'$sum': 1},
            "reviewer_name": {'$first': '$reviews.reviewer_name'}
        }
    },
    {
        "$project":{
            "_id": 1,
            "reviewer_name": 1,
            "num_reviews":1
        }
    },
    {
        '$sort': {'num_reviews': -1}
    },
    {
        '$limit': 20
    }
]

result = list(db.schema1.aggregate(pipeline))

pprint(result)
# Out:
# [{'_id': '20775242', 'num_reviews': 24, 'reviewer_name': 'Filipe'},
#  {'_id': '67084875', 'num_reviews': 13, 'reviewer_name': 'Nick'},
#  {'_id': '2961855', 'num_reviews': 10, 'reviewer_name': 'Uge'},
#  {'_id': '162027327', 'num_reviews': 9, 'reviewer_name': 'Thien'},
#  {'_id': '20991911', 'num_reviews': 9, 'reviewer_name': 'Lisa'},
#  {'_id': '12679057', 'num_reviews': 8, 'reviewer_name': 'Jodi'},
#  {'_id': '1705870', 'num_reviews': 8, 'reviewer_name': 'David'},
#  {'_id': '69140895', 'num_reviews': 8, 'reviewer_name': 'Lisa'},
#  {'_id': '60816198', 'num_reviews': 8, 'reviewer_name': 'Todd'},
#  {'_id': '55241576', 'num_reviews': 8, 'reviewer_name': 'Courtney'},
#  {'_id': '78093968', 'num_reviews': 7, 'reviewer_name': 'David'},
#  {'_id': '47303133', 'num_reviews': 7, 'reviewer_name': 'Lance'},
#  {'_id': '76782210', 'num_reviews': 6, 'reviewer_name': 'Assis'},
#  {'_id': '86665925', 'num_reviews': 6, 'reviewer_name': 'Chris'},
# ...

# %% [markdown]
# ### Question 10

# %% [markdown]
# 10)	For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). We are thinking we may soon add more metrics, although we don’t know what these will be. We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. Adjust the data model so this can be done and show the query for an example property.

# %%
pipeline = list(
    db.schema1.aggregate([
    {"$match": {"_id":"10006546"}
     },
    {
        "$addFields": {
            "review_scores": {
                "$objectToArray": "$$ROOT"
            }
        }
    },
    {
        "$unwind": "$review_scores"
    },
    {
        "$match": {
            "review_scores.k": {"$regex": "^review_scores_"}
        }
    },
    {
        "$group": {
            "_id": "$_id",
            "avg_review_scores": {"$avg": "$review_scores.v"}
        }
    }

]))

pprint(pipeline)
# Out:
# [{'_id': '10006546', 'avg_review_scores': 9.483333333333333}]

# %% [markdown]
# ### Question 11

# %% [markdown]
# 11.We wish to be able to have better access to information about transaction, we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.

# %%
start_date = datetime.datetime(2005, 1, 1)
end_date = datetime.datetime(2020, 12, 31)

pipeline = list(db.schema1.aggregate([
    {"$match": {"_id": "10009999"}},
    {"$unwind": "$transactions"},
    {"$unwind": "$transactions.transactions"},
    {"$match": {
        "transactions.transactions.date": {
            "$gte": start_date,
            "$lte": end_date
        }
    }},
    {"$group": {
        "_id": "$_id",
        "average_price": {"$avg": {"$toDouble": "$transactions.transactions.price"}}
    }}
]
))

pprint(pipeline)
# Out:
# [{'_id': '10009999', 'average_price': 120.99267462751442}]

# %% [markdown]
# ### Question 12

# %% [markdown]
# 12)	We wish to have a summary webpage that displays information about our top destinations. This webpage should display for each of the top 10 cities some basic information about our operations in the area (number of properties by type for example, average price by type) but you can choose the metrics. For each of the top 10 cities it should also provide some basic information about the top 3 properties in each city (price, number of review, whatever you think useful) to show an example of the properties available in the area. We would like to keep this webpage up to date as information changes.

# %%
# 12 A 

pipeline = list( db.listingsAndReviews_new.aggregate([ 
    
      {"$group" : {"_id": "$address.market", "Total Properties": { "$count" : { } }}},
      
      {"$project": {
        "_id": 0,
           "City" :"$_id",
          "Total Properties":1
        } },

      {"$sort": {"Total Properties": -1}},

      {"$limit": 10}


]))
# Save the names of the top 10 cities as a list
top_cities = [result['City'] for result in pipeline]
pprint(top_cities)
# Out:
# ['Istanbul',
#  'Montreal',
#  'Barcelona',
#  'Hong Kong',
#  'Sydney',
#  'New York',
#  'Rio De Janeiro',
#  'Porto',
#  'Oahu',
#  'Maui']

# %%
#12 B
# For each of the top 10 cities it will show the number of properties by type and average price by type
pipeline = list( db.schema1.aggregate([
    
    {"$match": {"address.market": {"$in": top_cities}}},

    {"$group": {"_id": {"city": "$address.market", "property_type": "$property_type"}, 
                "count": {"$sum": 1}, "price_on_average": {"$avg": "$price"}}},
    
    {"$project": {"_id": 0, "city": "$_id.city", "property_type": "$_id.property_type", 
                  "count": 1, "price_on_average": {"$round": ["$price_on_average", 2]},
                  "city_order": {"$indexOfArray": [top_cities, "$_id.city"]}}},
    {"$sort": {"city_order": 1, "count": -1}},
    {"$project": {"city_order": 0}}
]))

pprint(pipeline)
# Out:
# [{'city': 'Istanbul',
#   'count': 413,
#   'price_on_average': Decimal128('365.98'),
#   'property_type': 'Apartment'},
#  {'city': 'Istanbul',
#   'count': 67,
#   'price_on_average': Decimal128('314.42'),
#   'property_type': 'Serviced apartment'},
#  {'city': 'Istanbul',
#   'count': 37,
#   'price_on_average': Decimal128('276.30'),
#   'property_type': 'House'},
#  {'city': 'Istanbul',
#   'count': 30,
#   'price_on_average': Decimal128('290.67'),
#   'property_type': 'Boutique hotel'},
#  {'city': 'Istanbul',
#   'count': 26,
#   'price_on_average': Decimal128('594.77'),
#   'property_type': 'Bed and breakfast'},
#  {'city': 'Istanbul',
#   'count': 16,
#   'price_on_average': Decimal128('229.12'),
#   'property_type': 'Loft'},
#  {'city': 'Istanbul',
#   'count': 15,
#   'price_on_average': Decimal128('251.27'),
#   'property_type': 'Aparthotel'},
#  {'city': 'Istanbul',
#   'count': 13,
#   'price_on_average': Decimal128('956.00'),
#   'property_type': 'Hotel'},
# ...

# %%
#12 C
# For each of the top 3 properties in each city it will show price, number of reviews, accomodates and avg_review_scores_rating
pipeline = list(db.listingsAndReviews_new.aggregate([
    
    {"$match": {"address.market": {"$in": top_cities}}},
    
    {
        "$addFields": {
            "review_scores": {
                "$objectToArray": "$$ROOT"
            }
        }
    },
    
    {
        "$unwind": "$review_scores"
    },
    
    {
        "$match": {
            "review_scores.k": {"$regex": "^review_scores_"}
        }
    },
    
    {
        "$group": {
            "_id": {
                "address_market": "$address.market",
                "houses": "$_id"
            },
            "price": {"$first": "$price"},
            "accommodates": {"$first": "$accommodates"},
            "nr_reviews": {"$sum": {"$cond": [{"$isArray": "$reviews"}, {"$size": "$reviews"}, 0]}},
            "avg_review_scores_rating": {"$avg": "$review_scores.v"}
        }
    },
    
    {
        "$group": {
            "_id": "$_id.address_market",
            "houses": {
                "$push": {
                    "house_id": "$_id.houses",
                    "price": "$price",
                    "accommodates": "$accommodates",
                    "nr_reviews": "$nr_reviews",
                    "avg_review_scores_rating": "$avg_review_scores_rating"
                }
            }
        }

    },

    {
        "$project": {
            "_id": 1,  
            "city_order": {"$indexOfArray": [top_cities, "$_id"]},
            "houses": {
                "$slice": ["$houses", 3] 
            }
        }
    },
    
    {
        "$unwind": "$houses"
    },

    {
        "$project": {
            "_id": 1,
            "city_order": 1,
            "house_id": "$houses.house_id",
            "price": "$houses.price",
            "accommodates": "$houses.accommodates",
            "nr_reviews": "$houses.nr_reviews",
            "avg_review_scores_rating": {"$round": ["$houses.avg_review_scores_rating", 2]}
        }
    },

    {"$sort": { "city_order": 1, "avg_review_scores_rating": -1 }},
    {"$project": {"city_order": 0}}
]))

pprint(pipeline)
# Out:
# [{'_id': 'Istanbul',
#   'accommodates': 2,
#   'avg_review_scores_rating': 25.0,
#   'house_id': '24755982',
#   'nr_reviews': 6,
#   'price': Decimal128('301.00')},
#  {'_id': 'Istanbul',
#   'accommodates': 3,
#   'avg_review_scores_rating': 25.0,
#   'house_id': '27873052',
#   'nr_reviews': 24,
#   'price': Decimal128('100.00')},
#  {'_id': 'Istanbul',
#   'accommodates': 3,
#   'avg_review_scores_rating': 22.5,
#   'house_id': '7418073',
#   'nr_reviews': 12,
#   'price': Decimal128('506.00')},
#  {'_id': 'Montreal',
#   'accommodates': 2,
#   'avg_review_scores_rating': 23.83,
#   'house_id': '19550563',
#   'nr_reviews': 516,
#   'price': Decimal128('60.00')},
#  {'_id': 'Montreal',
#   'accommodates': 2,
#   'avg_review_scores_rating': 22.0,
#   'house_id': '27672638',
#   'nr_reviews': 36,
#   'price': Decimal128('81.00')},
#  {'_id': 'Montreal',
#   'accommodates': 5,
#   'avg_review_scores_rating': 16.67,
#   'house_id': '6358160',
#   'nr_reviews': 6,
# ...

# %% [markdown]
# ### Question 13

# %% [markdown]
# After you have completed the above tasks and have optimised your database show how you would complete each of the updates below. You can create whatever fictional data you like for the below. Remeber to cosider how to prevent any data you have previously created from becoming stale.
#
# 13)	Add a new property, this property should have a new host, and should be located in one of the top 10 cities. The host selects the top 10 most common amenities to be listed for the property.

# %%
# After getting the random city we need to get the correpondent country and generate a street

# Select a random top 10 city
city = random.choice(top_cities)
print("City:", city)

country_pipeline = [
    {"$match": {"address.market": city}},
    {"$group": {"_id": "$address.country"}},
    {"$project": {"_id": 0, "country": "$_id"}},
    {"$limit": 1},
]

country = list(db.schema1.aggregate(country_pipeline))

selected_country = country[0]["country"]
print("Country: " + selected_country)

street = f"{city}, {city}, {selected_country}"
print("Street: " + street)
# Out:
# City: Hong Kong
# Country: Hong Kong
# Street: Hong Kong, Hong Kong, Hong Kong

# %%
# Get the top 10 amenities
top_amenities = list(
    db.listingsAndReviews_new.aggregate([
        {"$unwind": "$amenities"},
        {"$group": {"_id": "$amenities", "count": {"$sum": 1}}},
        {"$sort": {"count": -1}},
        {"$limit": 10},
        {"$group": {"_id": None, "amenities": {"$push": "$_id"}}},
        {"$project": {"_id": 0, "amenities": 1}}
    ])
)[0]["amenities"]

print(top_amenities)
# Out:
# ['Wifi', 'Essentials', 'Kitchen', 'TV', 'Hangers', 'Hair dryer', 'Washer', 'Shampoo', 'Iron', 'Laptop friendly workspace']

# %%
# Insert the new document with the generated location information and top 10 amenities

from bson import Decimal128

document_new = db.schema1.insert_one({
     'name': "Perfect Country Rural location",
     'summary': 'The best place to enjoy a vacation after a hardworking semester!',
     'neighborhood_overview': 'Very friendly',
     'notes': 'Lapas, the house dog is very firendly and does not bite!',
    'transit' :'Next to the highway',
     'access': 'We are always available to help guests',
     'interaction': 'Cot - 10 € / night Dog - € 7,5 / night',
 'house_rules': 'Please recycle',
 'property_type': 'House',
 'room_type': 'Entire home/apt',
 'bed_type': 'Real Bed',
 'minimum_nights': 2,
 'maximum_nights': 30,
 'cancellation_policy': 'moderate',
 'accommodates': 8,
 'bedrooms': 3,
 'beds': 5,
 'number_of_reviews': 51,
 'bathrooms': Decimal128('3.0'),
 'amenities':top_amenities,
 'price': Decimal128('100.00'),
 'security_deposit': Decimal128('200.00'),
 'cleaning_fee': Decimal128('10.00'),
 'extra_people': Decimal128('15.00'),
 'guests_included': Decimal128('6'),
 'address': {'street': street,
  'market': city,
  'country': country},
 'host_about': 'Four Data Science friends!',
 'host_identity_verified': True,
 'host_is_superhost': True,
 'host_listings_count': 40,
 'host_name': 'Fernadina Fernunha',
 'host_response_rate': 100,
 'host_response_time': 'within an hour',
 'review_scores_checkin': 10,
 'review_scores_cleanliness':5,
 'review_scores_communication': 10,
 'review_scores_location': 10,
 'review_scores_rating': 10,
 'review_scores_value': 10
})

# %%
# Retain the id of the newly added listing
document = db.listingsAndReviews_new.find().sort([('_id', -1)]).limit(1)[0]
id_variable = document['_id']
print(document)
# Out:
# {'_id': ObjectId('644407564e219f22bc29598d'), 'name': 'Perfect Country Rural location', 'summary': 'The best place to enjoy a vacation after a hardworking semester!', 'neighborhood_overview': 'Very friendly', 'notes': 'Lapas, the house dog is very firendly and does not bite!', 'transit': 'Next to the highway', 'access': 'We are always available to help guests', 'interaction': 'Cot - 10 € / night Dog - € 7,5 / night', 'house_rules': 'Please recycle', 'property_type': 'House', 'room_type': 'Entire home/apt', 'bed_type': 'Real Bed', 'minimum_nights': 2, 'maximum_nights': 30, 'cancellation_policy': 'moderate', 'accommodates': 8, 'bedrooms': 3, 'beds': 5, 'number_of_reviews': 51, 'bathrooms': Decimal128('3.0'), 'amenities': ['Wifi', 'Essentials', 'Kitchen', 'TV', 'Hangers', 'Hair dryer', 'Washer', 'Shampoo', 'Iron', 'Laptop friendly workspace'], 'price': Decimal128('100.00'), 'security_deposit': Decimal128('200.00'), 'cleaning_fee': Decimal128('10.00'), 'extra_people': Decimal128('15.00')
# ...

# %% [markdown]
# ### Question 14

# %% [markdown]
# 14)	Add a new review to this property, the review should be from one of our top 20 reviewers.

# %%
# Find the top 10 reviewers
top_reviewers = list(
    db.reviews.aggregate([
        {"$unwind": "$reviews"},
        {"$group": {"_id": "$reviews.reviewer_name", "count": {"$sum": 1}}},
        {"$sort": {"count": -1}},
        {"$limit": 20},
        {"$group": {"_id": None, "reviewers": {"$push": "$_id"}}},
        {"$project": {"_id": 0, "reviewers": 1}}
    ])
)[0]["reviewers"]

print(top_reviewers)
# Out:
# ['David', 'Michael', 'Daniel', 'Sarah', 'Laura', 'John', 'Chris', 'Andrew', 'Jessica', 'Anna', 'Alex', 'James', 'Jennifer', 'Paul', 'Mark', 'Peter', 'Lisa', 'Maria', 'Michelle', 'Thomas']

# %%
# Add the review 

# Choose a random reviewer from the top_reviewers list
reviewer_name = random.choice(top_reviewers)
print("Reviewer name:", reviewer_name)

result = db.reviews.aggregate([
    {"$match": {"reviews.reviewer_name": reviewer_name}},
    {"$project": {"_id": 0, "reviewer_id": "$reviews.reviewer_id"}}
])

reviewer_id = result.next()["reviewer_id"]
print(f"Reviewer id for {reviewer_name}: {reviewer_id}")

new_review = db.reviews.insert_one({
    'reviews': {'date': datetime.now(),
    'listing_id': id_variable,
    'reviewer_id': reviewer_id,
    'reviewer_name': reviewer_name,
    'comments': 'Este Airbnb é simplesmente incrível! A localização é perfeita, o espaço é limpo e confortável e o anfitrião é extremamente acolhedor. Recomendo muito!'}

})

review_id = new_review.inserted_id
review = db.reviews.find_one({'_id': review_id})
review_id = new_review.inserted_id

# Put the review id on the listing document
db.schema1.update_one(
    {'_id': id_variable},
    {'$push': {'reviews': review_id}}
)
pprint(review)
# Out:
# Reviewer name: Sarah
# Reviewer id for Sarah: 4688794
# {'_id': ObjectId('64453c754e219f22bc29598f'),
#  'reviews': {'comments': 'Este Airbnb é simplesmente incrível! A localização é '
#                          'perfeita, o espaço é limpo e confortável e o '
#                          'anfitrião é extremamente acolhedor. Recomendo muito!',
#              'date': datetime.datetime(2023, 4, 23, 15, 11, 1, 937000),
#              'listing_id': ObjectId('644407564e219f22bc29598d'),
#              'reviewer_id': '4688794',
#              'reviewer_name': 'Sarah'}}

# %% [markdown]
# ### Question 15

# %% [markdown]
# 15)	Add a new review metric called x_factor to the new document and give a score of 10. Show that the average across all metrics is correctly calculated for this listing, with the query you previously developed.

# %%
# Create new variable on the new document

db.listingsAndReviews_new.update_one({'_id': id_variable}, {'$set': {'review_scores_x_factor': 10}})

# %%
# Show that the metric was created
document = db.listingsAndReviews_new.find({'_id': id_variable})

for x in document:
    pprint(x)
# Out:
# {'_id': ObjectId('644407564e219f22bc29598d'),
#  'access': 'We are always available to help guests',
#  'accommodates': 8,
#  'address': {'country': [{'country': 'Hong Kong'}],
#              'market': 'Hong Kong',
#              'street': 'Hong Kong, Hong Kong, Hong Kong'},
#  'amenities': ['Wifi',
#                'Essentials',
#                'Kitchen',
#                'TV',
#                'Hangers',
#                'Hair dryer',
#                'Washer',
#                'Shampoo',
#                'Iron',
#                'Laptop friendly workspace'],
#  'bathrooms': Decimal128('3.0'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 3,
#  'beds': 5,
#  'cancellation_policy': 'moderate',
#  'cleaning_fee': Decimal128('10.00'),
#  'extra_people': Decimal128('15.00'),
#  'guests_included': Decimal128('6'),
#  'host_about': 'Four Data Science friends!',
#  'host_identity_verified': True,
#  'host_is_superhost': True,
#  'host_listings_count': 40,
# ...

# %%
# Show that the pipeline works
pipeline = list(
    db.listingsAndReviews_new.aggregate([
    {"$match": {"_id":id_variable}
     },
    {
        "$addFields": {
            "review_scores": {
                "$objectToArray": "$$ROOT"
            }
        }
    },
    {
        "$unwind": "$review_scores"
    },
    {
        "$match": {
            "review_scores.k": {"$regex": "^review_scores_"}
        }
    },
    {
        "$group": {
            "_id": "$_id",
            "avg_review_scores": {"$avg": "$review_scores.v"}
        }
    }

]))

pprint(pipeline)
# Out:
# [{'_id': ObjectId('644407564e219f22bc29598d'),
#   'avg_review_scores': 9.285714285714286}]
